# %% [markdown]
# <a href="https://colab.research.google.com/github/Gamakek/Univercity/blob/main/Practical%20works/Practical%20work%20%E2%84%96%203.py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0, 0, 0)
# 0.5235987755982988
# False
# True
# 1.6

# %%
import math

class Sphere:
    def __init__(self, radius=1, x=0, y=0, z=0):
        self.radius = radius
        self.center = (x, y, z)

    def get_volume(self):
        return (4 / 3) * math.pi * (self.radius ** 3)

    def get_square(self):
        return 4 * math.pi * (self.radius ** 2)

    def get_radius(self):
        return self.radius

    def get_center(self):
        return self.center

    def set_radius(self, r):
        self.radius = r

    def set_center(self, x, y, z):
        self.center = (x, y, z)

    def is_point_inside(self, x, y, z):
        cx, cy, cz = self.center
        distance_squared = (x - cx) ** 2 + (y - cy) ** 2 + (z - cz) ** 2
        return distance_squared <= self.radius ** 2

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):
    def is_repeatance(self, s):
        if not isinstance(s, str):
            return False

        if len(s) == 0:
            return False

        if len(self) % len(s) != 0:
            return False

        repeat_count = len(self) // len(s)
        return self == s * repeat_count

    def is_palindrom(self):
        cleaned = ''.join(char.lower() for char in self if char.isalnum())

        if len(cleaned) <= 1:
            return True

        return cleaned == cleaned[::-1]

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)



class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []



class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

class Reviewer(Mentor):

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):

        if not isinstance(lecturer, Lecturer):
            print("Ошибка: лектор должен быть экземпляром класса Lecturer.")
            return

        if course not in self.courses_in_progress:
            print(f"Ошибка: вы не изучаете курс '{course}'.")
            return

        if course not in lecturer.courses_attached:
            print(f"Ошибка: лектор не прикреплён к курсу '{course}'.")
            return

        if grade < 1 or grade > 10:
            print("Ошибка: оценка должна быть от 1 до 10.")
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)
        print(f"Оценка {grade} выставлена лектору {lecturer.name} {lecturer.surname} за курс '{course}'.")



class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []



class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if not isinstance(student, Student):
            print("Ошибка: студент должен быть экземпляром класса Student.")
            return

        if course not in self.courses_attached:
            print(f"Ошибка: вы не прикреплены к курсу '{course}'.")
            return

        if course not in student.courses_in_progress:
            print(f"Ошибка: студент не изучает курс '{course}'.")
            return

        if grade < 1 or grade > 10:
            print("Ошибка: оценка должна быть от 1 до 10.")
            return

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)
        print(f"Оценка {grade} выставлена студенту {student.name} {student.surname} за курс '{course}'.")

    def __str__(self):
        return (f"Проверяющий\n"
                f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}")

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if not isinstance(lecturer, Lecturer):
            print("Ошибка: лектор должен быть экземпляром класса Lecturer.")
            return
        if course not in self.courses_in_progress:
            print(f"Ошибка: вы не изучаете курс '{course}'.")
            return
        if course not in lecturer.courses_attached:
            print(f"Ошибка: лектор не прикреплён к курсу '{course}'.")
            return
        if grade < 1 or grade > 10:
            print("Ошибка: оценка должна быть от 1 до 10.")
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)
        print(f"Оценка {grade} выставлена лектору {lecturer.name} {lecturer.surname} за курс '{course}'.")

    def get_average_hw_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.get_average_hw_grade()
        courses_in_progress = ", ".join(self.courses_in_progress) if self.courses_in_progress else "нет"
        finished_courses = ", ".join(self.finished_courses) if self.finished_courses else "нет"

        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {avg_grade:.1f}\n"
                f"Курсы в процессе изучения: {courses_in_progress}\n"
                f"Завершенные курсы: {finished_courses}")



class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []



class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def get_average_lecture_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.get_average_lecture_grade()
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за лекции: {avg_grade:.1f}")



class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if not isinstance(student, Student):
            print("Ошибка: студент должен быть экземпляром класса Student.")
            return
        if course not in self.courses_attached:
            print(f"Ошибка: вы не прикреплены к курсу '{course}'.")
            return
        if course not in student.courses_in_progress:
            print(f"Ошибка: студент не изучает курс '{course}'.")
            return
        if grade < 1 or grade > 10:
            print("Ошибка: оценка должна быть от 1 до 10.")
            return

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)
        print(f"Оценка {grade} выставлена студенту {student.name} {student.surname} за курс '{course}'.")

    def __str__(self):
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}")

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if not isinstance(lecturer, Lecturer):
            print("Ошибка: лектор должен быть экземпляром класса Lecturer.")
            return
        if course not in self.courses_in_progress:
            print(f"Ошибка: вы не изучаете курс '{course}'.")
            return
        if course not in lecturer.courses_attached:
            print(f"Ошибка: лектор не прикреплён к курсу '{course}'.")
            return
        if grade < 1 or grade > 10:
            print("Ошибка: оценка должна быть от 1 до 10.")
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)
        print(f"Оценка {grade} выставлена лектору {lecturer.name} {lecturer.surname} за курс '{course}'.")

    def get_average_hw_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.get_average_hw_grade()
        courses_in_progress = ", ".join(self.courses_in_progress) if self.courses_in_progress else "нет"
        finished_courses = ", ".join(self.finished_courses) if self.finished_courses else "нет"

        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {avg_grade:.1f}\n"
                f"Курсы в процессе изучения: {courses_in_progress}\n"
                f"Завершенные курсы: {finished_courses}")

    def __eq__(self, other):
        if not isinstance(other, Student):
            return NotImplemented
        return self.get_average_hw_grade() == other.get_average_hw_grade()

    def __lt__(self, other):
        if not isinstance(other, Student):
            return NotImplemented
        return self.get_average_hw_grade() < other.get_average_hw_grade()

    def __le__(self, other):
        if not isinstance(other, Student):
            return NotImplemented
        return self.get_average_hw_grade() <= other.get_average_hw_grade()



class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __str__(self):
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}")


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def get_average_lecture_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.get_average_lecture_grade()
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за лекции: {avg_grade:.1f}")

    def __eq__(self, other):
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.get_average_lecture_grade() == other.get_average_lecture_grade()

    def __lt__(self, other):
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.get_average_lecture_grade() < other.get_average_lecture_grade()

    def __le__(self, other):
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.get_average_lecture_grade() <= other.get_average_lecture_grade()

class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if not isinstance(student, Student):
            print("Ошибка: студент должен быть экземпляром класса Student.")
            return
        if course not in self.courses_attached:
            print(f"Ошибка: вы не прикреплены к курсу '{course}'.")
            return
        if course not in student.courses_in_progress:
            print(f"Ошибка: студент не изучает курс '{course}'.")
            return
        if grade < 1 or grade > 10:
            print("Ошибка: оценка должна быть от 1 до 10.")
            return

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)
        print(f"Оценка {grade} выставлена студенту {student.name} {student.surname} за курс '{course}'.")

    def __str__(self):
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}")

    def __call__(self):
        return f"Проверяющий {self.name} {self.surname}"


def average_hw_grade_by_course(students, course):
    all_grades = []
    for student in students:
        if course in student.grades:
            all_grades.extend(student.grades[course])
    return sum(all_grades) / len(all_grades) if all_grades else 0

def average_lecture_grade_by_course(lecturers, course):
    all_grades = []
    for lecturer in lecturers:
        if course in lecturer.grades:
            all_grades.extend(lecturer.grades[course])
    return sum(all_grades) / len(all_grades) if all_grades else 0

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
# Создаем студентов
student1 = Student("Алексей", "Петров", "мужской")
student1.courses_in_progress = ["Python", "Git"]
student1.finished_courses = ["Введение в программирование"]

student2 = Student("Мария", "Иванова", "женский")
student2.courses_in_progress = ["Python", "Базы данных"]
student2.finished_courses = ["Основы ООП"]

# Создаем лекторов
lecturer1 = Lecturer("Иван", "Сидоров")
lecturer1.courses_attached = ["Python", "Git"]

lecturer2 = Lecturer("Ольга", "Смирнова")
lecturer2.courses_attached = ["Python", "Базы данных"]

# Создаем проверяющих
reviewer1 = Reviewer("Дмитрий", "Кузнецов")
reviewer1.courses_attached = ["Python", "Git"]

reviewer2 = Reviewer("Анна", "Васильева")
reviewer2.courses_attached = ["Базы данных", "Python"]

# ====================== ВЫСТАВЛЕНИЕ ОЦЕНОК СТУДЕНТАМ ======================

print("=" * 50)
print("1. ВЫСТАВЛЕНИЕ ОЦЕНОК СТУДЕНТАМ:")
print("=" * 50)

# Корректные оценки
reviewer1.rate_hw(student1, "Python", 9)
reviewer1.rate_hw(student1, "Python", 8)
reviewer1.rate_hw(student1, "Git", 10)

reviewer1.rate_hw(student2, "Python", 7)
reviewer2.rate_hw(student2, "Python", 8)
reviewer2.rate_hw(student2, "Базы данных", 9)

# Проверка ошибок
reviewer1.rate_hw(student1, "Базы данных", 5)
reviewer2.rate_hw(student1, "Python", 11)
# ====================== ВЫСТАВЛЕНИЕ ОЦЕНОК ЛЕКТОРАМ ======================

print("\n" + "=" * 50)
print("2. ВЫСТАВЛЕНИЕ ОЦЕНОК ЛЕКТОРАМ:")
print("=" * 50)

# Корректные оценки
student1.rate_lecturer(lecturer1, "Python", 9)
student1.rate_lecturer(lecturer1, "Git", 10)
student2.rate_lecturer(lecturer1, "Python", 8)

student1.rate_lecturer(lecturer2, "Python", 7)
student2.rate_lecturer(lecturer2, "Python", 9)
student2.rate_lecturer(lecturer2, "Базы данных", 8)

# Проверка ошибок
student1.rate_lecturer(lecturer1, "Базы данных", 5)
student2.rate_lecturer(lecturer2, "Git", 6)

# ====================== ПРОВЕРКА МЕТОДОВ __str__ ======================

print("\n" + "=" * 50)
print("3. ИНФОРМАЦИЯ О ВСЕХ УЧАСТНИКАХ:")
print("=" * 50)

print("\n--- СТУДЕНТЫ ---")
print(f"\n{student1}\n")
print(f"\n{student2}\n")

print("\n--- ЛЕКТОРЫ ---")
print(f"\n{lecturer1}\n")
print(f"\n{lecturer2}\n")

print("\n--- ПРОВЕРЯЮЩИЕ ---")
print(f"\n{reviewer1}\n")
print(f"\n{reviewer2}\n")

# ====================== ПРОВЕРКА СРАВНЕНИЯ ======================

print("\n" + "=" * 50)
print("4. СРАВНЕНИЕ СТУДЕНТОВ И ЛЕКТОРОВ:")
print("=" * 50)

print(f"Средний балл студента1: {student1.get_average_hw_grade():.1f}")
print(f"Средний балл студента2: {student2.get_average_hw_grade():.1f}")
print(f"student1 == student2: {student1 == student2}")


print(f"\nСредний балл лектора1: {lecturer1.get_average_lecture_grade():.1f}")
print(f"Средний балл лектора2: {lecturer2.get_average_lecture_grade():.1f}")
print(f"lecturer1 == lecturer2: {lecturer1 == lecturer2}")


# ====================== ПРОВЕРКА ФУНКЦИЙ ДЛЯ ПОДСЧЕТА СРЕДНИХ ОЦЕНОК ======================

print("\n" + "=" * 50)
print("6. СРЕДНИЕ ОЦЕНКИ ПО КУРСАМ:")
print("=" * 50)

# Создаем списки для функций
students_list = [student1, student2]
lecturers_list = [lecturer1, lecturer2]

# Средняя оценка за домашние задания по курсу Python
avg_hw_python = average_hw_grade_by_course(students_list, "Python")
print(f"Средняя оценка за ДЗ по курсу 'Python' (все студенты): {avg_hw_python:.1f}")

# Средняя оценка за домашние задания по курсу Git
avg_hw_git = average_hw_grade_by_course(students_list, "Git")
print(f"Средняя оценка за ДЗ по курсу 'Git' (все студенты): {avg_hw_git:.1f}")

# Средняя оценка за лекции по курсу Python
avg_lecture_python = average_lecture_grade_by_course(lecturers_list, "Python")
print(f"Средняя оценка за лекции по курсу 'Python' (все лекторы): {avg_lecture_python:.1f}")

# Средняя оценка за лекции по курсу Git
avg_lecture_git = average_lecture_grade_by_course(lecturers_list, "Git")
print(f"Средняя оценка за лекции по курсу 'Git' (все лекторы): {avg_lecture_git:.1f}")
# Out:
# ==================================================
# 1. ВЫСТАВЛЕНИЕ ОЦЕНОК СТУДЕНТАМ:
# ==================================================
# Оценка 9 выставлена студенту Алексей Петров за курс 'Python'.
# Оценка 8 выставлена студенту Алексей Петров за курс 'Python'.
# Оценка 10 выставлена студенту Алексей Петров за курс 'Git'.
# Оценка 7 выставлена студенту Мария Иванова за курс 'Python'.
# Оценка 8 выставлена студенту Мария Иванова за курс 'Python'.
# Оценка 9 выставлена студенту Мария Иванова за курс 'Базы данных'.
# Ошибка: вы не прикреплены к курсу 'Базы данных'.
# Ошибка: оценка должна быть от 1 до 10.
#
# ==================================================
# 2. ВЫСТАВЛЕНИЕ ОЦЕНОК ЛЕКТОРАМ:
# ==================================================
# Оценка 9 выставлена лектору Иван Сидоров за курс 'Python'.
# Оценка 10 выставлена лектору Иван Сидоров за курс 'Git'.
# Оценка 8 выставлена лектору Иван Сидоров за курс 'Python'.
# Оценка 7 выставлена лектору Ольга Смирнова за курс 'Python'.
# Оценка 9 выставлена лектору Ольга Смирнова за курс 'Python'.
# Оценка 8 выставлена лектору Ольга Смирнова за курс 'Базы данных'.
# Ошибка: вы не изучаете курс 'Базы данных'.
# Ошибка: вы не изучаете курс 'Git'.
#
# ==================================================
# 3. ИНФОРМАЦИЯ О ВСЕХ УЧАСТНИКАХ:
# ==================================================
#
# --- СТУДЕНТЫ ---
#
# Имя: Алексей
# Фамилия: Петров
# Средняя оценка за домашние задания: 9.0
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
#
#
# Имя: Мария
# Фамилия: Иванова
# Средняя оценка за домашние задания: 8.0
# Курсы в процессе изучения: Python, Базы данных
# Завершенные курсы: Основы ООП
#
#
# --- ЛЕКТОРЫ ---
#
# Имя: Иван
# Фамилия: Сидоров
# Средняя оценка за лекции: 9.0
#
#
# Имя: Ольга
# Фамилия: Смирнова
# Средняя оценка за лекции: 8.0
#
#
# --- ПРОВЕРЯЮЩИЕ ---
#
# Имя: Дмитрий
# Фамилия: Кузнецов
#
#
# Имя: Анна
# Фамилия: Васильева
#
#
# ==================================================
# 4. СРАВНЕНИЕ СТУДЕНТОВ И ЛЕКТОРОВ:
# ==================================================
# Средний балл студента1: 9.0
# Средний балл студента2: 8.0
# student1 == student2: False
#
# Средний балл лектора1: 9.0
# Средний балл лектора2: 8.0
# lecturer1 == lecturer2: False
#
# ==================================================
# 6. СРЕДНИЕ ОЦЕНКИ ПО КУРСАМ:
# ==================================================
# Средняя оценка за ДЗ по курсу 'Python' (все студенты): 8.0
# Средняя оценка за ДЗ по курсу 'Git' (все студенты): 10.0
# Средняя оценка за лекции по курсу 'Python' (все лекторы): 8.2
# Средняя оценка за лекции по курсу 'Git' (все лекторы): 10.0

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
import math

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Знаменатель не может быть нулём")
        self.numerator = int(numerator)
        self.denominator = int(denominator)
        self._simplify()

    def _simplify(self):
        """Упрощает дробь до несократимой."""
        gcd = math.gcd(abs(self.numerator), abs(self.denominator))
        self.numerator //= gcd
        self.denominator //= gcd

        # Обеспечиваем положительный знаменатель
        if self.denominator < 0:
            self.numerator = -self.numerator
            self.denominator = -self.denominator

    @classmethod
    def from_float(cls, value):
        """Создаёт дробь из числа с плавающей точкой."""
        # Преобразуем float в дробь, используя точность
        from fractions import Fraction as Frac
        f = Frac(value).limit_denominator()
        return cls(f.numerator, f.denominator)

    def __add__(self, other):
        if isinstance(other, Fraction):
            new_numerator = (self.numerator * other.denominator +
                             other.numerator * self.denominator)
            new_denominator = self.denominator * other.denominator
            return Fraction(new_numerator, new_denominator)
        return NotImplemented

    def __sub__(self, other):
        if isinstance(other, Fraction):
            new_numerator = (self.numerator * other.denominator -
                             other.numerator * self.denominator)
            new_denominator = self.denominator * other.denominator
            return Fraction(new_numerator, new_denominator)
        return NotImplemented

    def __mul__(self, other):
        if isinstance(other, Fraction):
            new_numerator = self.numerator * other.numerator
            new_denominator = self.denominator * other.denominator
            return Fraction(new_numerator, new_denominator)
        return NotImplemented

    def __truediv__(self, other):
        if isinstance(other, Fraction):
            if other.numerator == 0:
                raise ZeroDivisionError("Деление на нулевую дробь")
            new_numerator = self.numerator * other.denominator
            new_denominator = self.denominator * other.numerator
            return Fraction(new_numerator, new_denominator)
        return NotImplemented

    def __eq__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator == other.numerator and
                    self.denominator == other.denominator)
        return NotImplemented

    def __lt__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator <
                    other.numerator * self.denominator)
        return NotImplemented

    def __le__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator <=
                    other.numerator * self.denominator)
        return NotImplemented

    def __gt__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator >
                    other.numerator * self.denominator)
        return NotImplemented

    def __ge__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator >=
                    other.numerator * self.denominator)
        return NotImplemented

    def reciprocal(self):
        """Возвращает обратную дробь."""
        if self.numerator == 0:
            raise ZeroDivisionError("Обратная дробь для нуля не существует")
        return Fraction(self.denominator, self.numerator)

    def __float__(self):
        return self.numerator / self.denominator

    def __str__(self):
        if self.denominator == 1:
            return str(self.numerator)
        return f"{self.numerator}/{self.denominator}"

    def __repr__(self):
        return f"Fraction({self.numerator}, {self.denominator})"

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# 19/12
# -1/12
# 5/8
# 9/10
# True
# False
# True
# 0.75
# 4/3
# 3/4
# Знаменатель не может быть нулём
# 3/4
# Fraction(3, 4)
