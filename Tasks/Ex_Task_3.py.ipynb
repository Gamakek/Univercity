# %% [markdown]
# <a href="https://colab.research.google.com/github/Gamakek/Univercity/blob/main/Tasks/Ex_Task_3.py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Дополнительное задание №3. Обработка исключений и работа с текстовыми файлами**

# %% [markdown]
# **БАЗА:**
#
# - **Обработка исключений** позволяет перехватывать и обрабатывать ошибки, возникающие при выполнении программы, предотвращая её аварийное завершение.
# - **Работа с файлами** - важный навык для чтения, записи и обработки текстовой информации в Python.
#
# ---

# %% [markdown]
# ## **I. Обработка исключений**

# %% [markdown]
# ### **Пункт №1. Обработка некорректного индекса (IndexError)**

# %% [markdown]
# Создайте список из нескольких элементов (например, [10, 20, 30]). Попросите пользователя ввести индекс элемента, который нужно вывести. Если пользователь введёт индекс, выходящий за границы списка, перехватите IndexError и сообщите об этом.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте список из минимум 5 элементов
# - Покажите содержимое списка перед работой
# - Протестируйте минимум 4 случая (корректный индекс, отрицательный, слишком большой, нечисловое значение)

# %%
s = [1, 2, 3, 4, 5]
for i in range(4):
  try:
    ind = int(input('Введите индекс: '))
    print(s[ind])
  except IndexError:
    print('Не корректный индекс!!!')
  except ValueError:
    print('Это не цифры!!!')
# Out:
# Введите индекс: 2
# 3
# Введите индекс: -3
# 3
# Введите индекс: 123
# Не корректный индекс!!!
# Введите индекс: афв
# Это не цифры!!!

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Обработка исключений в цикле**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя числа и добавляет их в список.
# - Если пользователь вводит некорректные данные, программа должна выводить сообщение об ошибке и продолжать работу.
# - Для выхода из программы пользователь должен ввести "стоп".
#
# **ОБЯЗАТЕЛЬНО:**
# - Покажите процесс ввода минимум 7 значений (включая ошибочные)
# - Выведите финальный список и статистику (сколько чисел введено успешно, сколько ошибок)

# %% [markdown]
# ```
# # Пример:
# # Введите число: 10
# # Введите число: текст (Ошибка: это не число)
# # Введите число: стоп
# # Итоговый список: [10]
# ```

# %%
s = []
cnt_1 = 0
cnt_0 = 0
while True:
    try:
        d = input()
        if d.lower() == 'стоп':
            print(f"Чисел введено успешно: {cnt_1}\nЧисел введено неверно: {cnt_0}\nИтоговый список:{s}")
            break
        s.append(int(d))
        cnt_1 += 1
    except ValueError:
        print("Ошибка: это не число!!!")
        cnt_0 += 1
# Out:
# 1
# ada
# Ошибка: это не число!!!
# 4
# 6
# 3
# ав
# Ошибка: это не число!!!
# fwfw
# Ошибка: это не число!!!
# 45
# Стоп
# Чисел введено успешно: 5
# Чисел введено неверно: 3
# Итоговый список:[1, 4, 6, 3, 45]

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3**

# %% [markdown]
# Создайте функцию `get_list_element(lst, index)`, которая безопасно извлекает элемент списка по индексу с использованием блоков `try`, `except`, `else` и `finally`.
#
# Функция должна:
# - Обрабатывать выход за пределы списка
# - Обрабатывать некорректный тип индекса
# - Выводить сообщение о попытке доступа в блоке `finally`
#
# **ОБЯЗАТЕЛЬНО:**
# - Выведите результаты для минимум 4 различных случаев (успешный доступ, выход за границы, отрицательный индекс, нечисловой индекс)
# - Покажите, что блок `finally` выполняется всегда
#
# ```python
# # Пример использования:
# my_list = [1, 2, 3, 4, 5]
# get_list_element(my_list, 2)   # Вывод: "Элемент: 3", "Попытка доступа завершена"
# get_list_element(my_list, 10)  # Вывод: "Индекс вне диапазона", "Попытка доступа завершена"
# ```

# %%
def get_list_element(lst, index):
  try:
    n = lst[int(index)]
  except IndexError:
    print('Индекс вне диапазона!')
  except ValueError:
    print('Некорректный тип индекса!')
  else:
    print(f'Элемент ', n)
  finally:
    print('Попытка доступа завершена')

my_list = [1, 2, 3, 4, 5]
for _ in range(4):
  get_list_element(my_list, input())
# Out:
# 2
# Элемент  3
# Попытка доступа завершена
# -1
# Элемент  5
# Попытка доступа завершена
# dad
# Некорректный тип индекса!
# Попытка доступа завершена
# 1331
# Индекс вне диапазона!
# Попытка доступа завершена

# %% [markdown]
# ---

# %% [markdown]
# ## **II. Работа с текстовыми файлами**

# %% [markdown]
# ### **Пункт №1. Запись в файл**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя строку и записывает её в файл output.txt в режиме дозаписи.
#
# **ОБЯЗАТЕЛЬНО:**
# - Запросите у пользователя минимум 3 строки
# - Покажите содержимое файла после записи

# %%
with open('output.txt', mode = 'w', encoding = 'utf8') as text:
  s = []
  for i in range(3):
    s.append(input('Введите строку: ') + '\n')
  text.writelines(s)

with open('output.txt', mode = 'r', encoding = 'utf8')  as text:
  f = text.read()
  print('Содержимое файла:')
  print(f)
# Out:
# Введите строку: daogkajliaha
# Введите строку: gahgakjkugaku
# Введите строку: gkagkauhgiaha
# Содержимое файла:
# daogkajliaha
# gahgakjkugaku
# gkagkauhgiaha

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Чтение из файла**

# %% [markdown]
# Напишите программу, которая открывает файл dota2.txt и выводит его содержимое на экран.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 5 строками текста
# - Покажите содержимое файла целиком
# - Обработайте случай отсутствующего файла

# %%
s = ['Marci\n', 'Pudge\n', 'Mars\n', 'Ursa\n', 'Void Spirit']
with open('dota2.txt', mode = 'w', encoding = 'utf8') as dota2:
  dota2.writelines(s)

try:
  with open('dota2.txt', encoding = 'utf8') as dota2:
    f = dota2.read()
    print(f)
except FileNotFoundError:
  print('Файла не существует!!!')
# Out:
# Marci
# Pudge
# Mars
# Ursa
# Void Spirit

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3. Подсчет строк в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и подсчитывает количество строк в нём.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с известным количеством строк (минимум 10)
# - Покажите первые 3 строки файла
# - Выведите общее количество строк
# - Выведите количество непустых строк

# %%
s = ["Пицца\n", "Паста\n", "Салат\n", "\n", "Суп\n", "Стейк\n", "\n", "Роллы\n", "Шашлык\n", "\n", "Плов\n", "Бургер\n", "\n", "Такос"]
with open('output.txt', mode = 'w', encoding = 'utf8') as text:
  text.writelines(s)

cnt_1 = 0
cnt = 0

with open('output.txt', encoding = 'utf8') as text:
  f = text.readlines()
  for i in range(3):
    print(f[i].rstrip())
  for i in range(len(f)):
    if f[i].strip() != '':
      cnt_1 += 1
    cnt += 1
print(f'Общее колличество строк: {cnt}\nКолличество непустых строк: {cnt_1}')
# Out:
# Пицца
# Паста
# Салат
# Общее колличество строк: 14
# Колличество непустых строк: 10

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №4. Копирование содержимого файла**

# %% [markdown]
# Напишите программу, которая копирует содержимое файла input.txt в файл output.txt.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте исходный файл с тестовым содержимым (минимум 5 строк)
# - Покажите содержимое исходного файла
# - Выполните копирование
# - Покажите содержимое скопированного файла
# - Обработайте случай отсутствия исходного файла

# %%
s = ["Александр\n", "Димитрис\n", "Елена\n", "София\n", "Николас"]
with open('input.txt', mode = 'w+', encoding = 'utf8') as text:
  text.writelines(s)
try:
  with open('input.txt', mode = 'r', encoding = 'utf8') as text:
    f = text.read()
    print('Исходный файл:', f.splitlines())
  with open('input.txt', 'rb') as source:
      with open('output.txt', 'wb') as target:
          target.write(source.read())
  with open('output.txt', encoding = 'utf8') as text_copy:
    g = text_copy.read()
    print('Скопированный файл:', g.splitlines())
except FileNotFoundError:
  print('Файла не существует')
# Out:
# Исходный файл: ['Александр', 'Димитрис', 'Елена', 'София', 'Николас']
# Скопированный файл: ['Александр', 'Димитрис', 'Елена', 'София', 'Николас']

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №5. Поиск слова в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и проверяет, содержится ли в нём слово, введённое пользователем.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 10 строками текста
# - Покажите содержимое файла
# - Протестируйте поиск минимум 5 различных слов
# - Выведите номера строк, где найдено слово
# - Покажите количество вхождений слова

# %%
txt = [
    "Яблоко красное и сладкое\n",
    "Банан желтый и мягкий\n",
    "Апельсин оранжевый сочный\n",
    "Яблоко зеленое кислое\n",
    "Виноград синий и сладкий\n",
    "Банан длинный и свежий\n",
    "Киви зеленый мохнатый\n",
    "Яблоко спелое и ароматное\n",
    "Апельсин сладкий цитрус\n",
    "Банан спелый желтый фрукт"
]
with open('output.txt', mode = 'w', encoding = 'utf8') as text:
  text.writelines(txt)

def findwords(file_name, finding_word):
  found_words = []
  cnt_in = 0
  with open(f'{file_name}', mode = 'r', encoding = 'utf8') as text:
    t = text.readlines()
    for i in range(len(t)):
      if finding_word in t[i]:
        found_words.append(i + 1)
        cnt_in += 1
  return [found_words, cnt_in]
f_words = ['Яблоко', 'Банан', 'Апельсин', 'зеленый', 'сладкий']
for i in f_words:
  f = findwords('output.txt', i)
  print(f'Строчки, в которых нвйдены слова: {f[0]}\nВсего вхождений: {f[1]}')
# Out:
# Строчки, в которых нвйдены слова: [1, 4, 8]
# Всего вхождений: 3
# Строчки, в которых нвйдены слова: [2, 6, 10]
# Всего вхождений: 3
# Строчки, в которых нвйдены слова: [3, 9]
# Всего вхождений: 2
# Строчки, в которых нвйдены слова: [7]
# Всего вхождений: 1
# Строчки, в которых нвйдены слова: [5, 9]
# Всего вхождений: 2

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №6. Чтение файла с обработкой FileNotFoundError**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя имя файла и пытается открыть его. Если файла не существует, перехватите FileNotFoundError и выведите сообщение «Файл не найден!».
#
# **ОБЯЗАТЕЛЬНО:**
# - Протестируйте с существующим файлом
# - Протестируйте с несуществующим файлом
# - Покажите содержимое существующего файла

# %%
def findf(filename):
  try:
    with open(f'{filename}', encoding = 'utf8') as text:
      f = text.readlines()
      print(f)
  except FileNotFoundError:
    print('Файла не существует!!!')
findf('input.txt')
findf('dota.txt')
# Out:
# ['Александр\n', 'Димитрис\n', 'Елена\n', 'София\n', 'Николас']
# Файла не существует!!!

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №7. Подсчет статистики файла**

# %% [markdown]
# Напишите функцию `file_statistics(filename)`, которая читает текстовый файл и возвращает словарь со статистикой:
# - Количество строк
# - Количество слов
# - Количество символов (с пробелами и без)
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с минимум 5 строками текста
# - Выведите содержимое файла ДО обработки
# - Выведите полученную статистику
# - Обработайте случай несуществующего файла
#
# ```python
# # Создание тестового файла
# test_content = """Первая строка текста
# Вторая строка с большим количеством слов
# Третья строка
# Четвертая строка для теста
# Пятая и последняя строка"""
#
# # Сохраните в файл и продемонстрируйте работу
# ```

# %%
def file_info(filename):
    try:
        with open(filename, encoding='utf8') as text:
            rd = text.read()
            text.seek(0)
            rdlns = text.readlines()
            print('Количество строк:', len(rdlns))
            print('Количество слов:', len(rd.split()))
            print('Количество символов с пробелом:', len(rd))
            print('Количество символов без пробелов:', len(rd.replace(' ', '').replace('\n', '')))
    except FileNotFoundError:
        print('Файла не существует!!!')

test_content = ['Первая строка текста\n', 'Вторая строка с большим количеством слов\n', 'Третья строка\n', 'Четвертая строка для теста\n', 'Пятая и последняя строка']
with open('output.txt', mode='w+', encoding='utf8') as text:
    text.writelines(test_content)

import builtins
input = builtins.input

with open('output.txt', encoding = 'utf8') as text:
  s = text.readlines()
  print(s)
while True:

    name = input('Введите название файла: ')
    if name == 'Stop':
      break
    file_info(name)
# Out:
# ['Первая строка текста\n', 'Вторая строка с большим количеством слов\n', 'Третья строка\n', 'Четвертая строка для теста\n', 'Пятая и последняя строка']
# Введите название файла: output.txt
# Количество строк: 5
# Количество слов: 19
# Количество символов с пробелом: 127
# Количество символов без пробелов: 109
# Введите название файла: dada
# Файла не существует!!!
# Введите название файла: Stop

# %% [markdown]
# ### **Пункт №8. Поиск и замена в файле**

# %% [markdown]
# Напишите функцию `replace_in_file(filename, old_text, new_text)`, которая заменяет все вхождения `old_text` на `new_text` в файле и сохраняет результат в новый файл с префиксом "modified_".
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с текстом, содержащим минимум 3 вхождения заменяемого слова
# - Выведите содержимое файла ДО замены
# - Выполните замену
# - Выведите содержимое файла ПОСЛЕ замены
# - Покажите количество произведенных замен

# %%
def replace_in_file(filename, old_text, new_text):
    cnt = 0
    with open(filename, encoding='utf8') as text:
        s = text.read()
        print('До замены:', s)
        s = s.replace(old_text, new_text)
        cnt = s.count(new_text)
        with open('modified_' + filename, mode='w', encoding='utf8') as text_modified:  # Изменено имя переменной
            text_modified.write(s)

    with open('modified_' + filename, mode='r', encoding='utf8') as text_modified:
        a = text_modified.read()
        print('После замены:', a)
        print(f'Количество замен: {cnt}')

c = ['I am pible wash my belly I am pible clean my belly']
with open('output.txt', mode='w', encoding='utf8') as text:
    text.writelines(c)

replace_in_file('output.txt', 'pible', 'PIBLE')
# Out:
# До замены: I am pible wash my belly I am pible clean my belly
# После замены: I am PIBLE wash my belly I am PIBLE clean my belly
# Количество замен: 2

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №9. Объединение файлов**

# %% [markdown]
# Создайте функцию `merge_files(file_list, output_file)`, которая объединяет содержимое нескольких текстовых файлов в один, добавляя после каждого разделитель.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте минимум 3 файла с разным содержимым
# - Выведите содержимое КАЖДОГО исходного файла
# - Выполните объединение
# - Выведите содержимое результирующего файла

# %%
def merge_files(file_list, output_file):

    with open(output_file, 'w', encoding='utf8') as out_file:
        for filename in file_list:
            print(filename + ':')
            with open(filename, 'r', encoding='utf8') as in_file:
                content = in_file.read()
                print(content)
                out_file.write(content)
                if filename != file_list[-1]:
                    out_file.write('\n')

    print(f"\nСодержимое объединенного файла {output_file}:")
    with open(output_file, 'r', encoding='utf8') as res_file:
        print(res_file.read())

files_data = {
    'file1.txt': 'Это текст для первого файла',
    'file2.txt': 'А это для второго\nЕще для второго',
    'file3.txt': 'А это уже для третьего'
}

for filename, content in files_data.items():
    with open(filename, 'w', encoding='utf8') as f:
        f.write(content)

merge_files(['file1.txt', 'file2.txt', 'file3.txt'], 'merged_result.txt')
# Out:
# file1.txt:
# Это текст для первого файла
# file2.txt:
# А это для второго
# Еще для второго
# file3.txt:
# А это уже для третьего
#
# Содержимое объединенного файла merged_result.txt:
# Это текст для первого файла
# А это для второго
# Еще для второго
# А это уже для третьего

# %% [markdown]
# ---
